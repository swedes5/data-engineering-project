# %%
import pandas as pd
import io
import requests

import pyodbc

# %%
url = 'https://aqs.epa.gov/data/api/list/states?email=test@aqs.api&key=test'
r = requests.get(url)
text = r.text

# %%
type(text)

# %%
state_keys_json = r.json()
state_keys_json.keys()

# %%
type(state_keys_json['Data'])

# %%
df = pd.DataFrame(state_keys_json['Data'])

# %%
df

# %%
url2 = 'https://aqs.epa.gov/data/api/list/classes?email=test@aqs.api&key=test'
r2 = requests.get(url2)

# %%
param_keys_json = r2.json()
param_keys_json.keys()

# %%
df2 = pd.DataFrame(param_keys_json['Data'])

# %%
df2

# %%
#url 3 refers to a sample request to see if api was returning data

url3 = 'https://aqs.epa.gov/data/api/sampleData/byState?email=test@aqs.api&key=test&param=45201&bdate=19950101&edate=19951231&state=37'
#url3 = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=81104&bdate=20200101&edate=20201230&state=37'
r3 = requests.get(url3)
data_2half_json = r3.json() #data for particulates 2.5 micrometers
data_2half_json.keys()

# %%
df3 = pd.DataFrame(data_2half_json['Data'])
df3['date_local'].unique

# %%
df3.columns

# %%
df3_new = df3[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]

# %%
df3_by_desc = df3_new.sort_values(by=['sample_measurement'], ascending=False)
df3_by_desc

# %%
#using this type of requests can i make a dashboard where users can see the worst states/counties in the USA by parameter (ex benzene) and date

#ex:   select type of particulate:    select year:    

#returns: top 10 and bottom 10 counties/states for this type of air particulate in usa

# %%
#benzene in 2017 in california
url4 = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=45201&bdate=20170101&edate=20171231&state=06'
r4 = requests.get(url4)
data_benzene_json = r4.json()
df4 = pd.DataFrame(data_benzene_json['Data'])

# %%
df4 = df4[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']].sort_values(by=['sample_measurement'], ascending=False)
df4

# %%
#try to get df for all states/benzene for 2015-2020

# %%
#trying to get df for all states/benzene for 2017

base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=45201&bdate=20170101&edate=20171231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_benzene_2017 = urls_list + urls_list2

# %%
#checking list of links looks correct
urls_list_benzene_2017

# %%
df_benzene_2017 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

for url in urls_list_benzene_2017:
    r = requests.get(url)
    data_benzene_json = r.json()
    df = pd.DataFrame(data_benzene_json['Data'])
    #df = df[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
    df_benzene_2017 = pd.concat([df_benzene_2017, df])

# %%
df_benzene_2017 = df_benzene_2017[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_benzene_2017

# %%
#trying to get df for all states/benzene for 2016

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=45201&bdate=20160101&edate=20161231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_benzene_2016 = urls_list + urls_list2


#creating a base df
df_benzene_2016 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_benzene_2016:
    r = requests.get(url)
    data_benzene_json = r.json()
    df = pd.DataFrame(data_benzene_json['Data'])
    df_benzene_2016 = pd.concat([df_benzene_2016, df])

#keeping desired rows    
df_benzene_2016 = df_benzene_2016[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_benzene_2016

# %%
#trying to get df for all states/benzene for 2015

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=45201&bdate=20150101&edate=20151231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_benzene_2015 = urls_list + urls_list2


#creating a base df
df_benzene_2015 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_benzene_2015:
    r = requests.get(url)
    data_benzene_json = r.json()
    df = pd.DataFrame(data_benzene_json['Data'])
    df_benzene_2015 = pd.concat([df_benzene_2015, df])

#keeping desired rows    
df_benzene_2015 = df_benzene_2015[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_benzene_2015

# %%
#trying to get df for all states/benzene for 2018

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=45201&bdate=20180101&edate=20181231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_benzene_2018 = urls_list + urls_list2


#creating a base df
df_benzene_2018 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_benzene_2018:
    r = requests.get(url)
    data_benzene_json = r.json()
    df = pd.DataFrame(data_benzene_json['Data'])
    df_benzene_2018 = pd.concat([df_benzene_2018, df])

#keeping desired rows    
df_benzene_2018 = df_benzene_2018[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_benzene_2018

# %%
#trying to get df for all states/benzene for 2019

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=45201&bdate=20190101&edate=20191231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_benzene_2019 = urls_list + urls_list2


#creating a base df
df_benzene_2019 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_benzene_2019:
    r = requests.get(url)
    data_benzene_json = r.json()
    df = pd.DataFrame(data_benzene_json['Data'])
    df_benzene_2019 = pd.concat([df_benzene_2019, df])

#keeping desired rows    
df_benzene_2019 = df_benzene_2019[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_benzene_2019

# %%
#trying to get df for all states/benzene for 2020

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=45201&bdate=20200101&edate=20201231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_benzene_2020 = urls_list + urls_list2


#creating a base df
df_benzene_2020 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_benzene_2020:
    r = requests.get(url)
    data_benzene_json = r.json()
    df = pd.DataFrame(data_benzene_json['Data'])
    df_benzene_2020 = pd.concat([df_benzene_2020, df])

#keeping desired rows    
df_benzene_2020 = df_benzene_2020[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_benzene_2020

# %%
#checking that the dfs were created correctly by looking at the shapes
#also concat to one single df 
print(df_benzene_2015.shape)
print(df_benzene_2016.shape)
print(df_benzene_2017.shape)
print(df_benzene_2018.shape)
print(df_benzene_2019.shape)
print(df_benzene_2020.shape)

benzene_dfs_temp = [df_benzene_2015,df_benzene_2016,df_benzene_2017,df_benzene_2018,df_benzene_2019,df_benzene_2020]

benzene_dfs = pd.concat(benzene_dfs_temp)


print(benzene_dfs.shape)

# %%
#dropping all rows with a null value

benzene_dfs = benzene_dfs.dropna()

print(benzene_dfs.shape)

# %%
#creating csv from the combined df for addition to sqlite db

benzene_dfs.to_csv('benzene.csv', index=False)

# %%
#creating connection to sql db
from sqlalchemy import create_engine
engine = create_engine('sqlite:///AQ_engineering_db.db', echo=False)

# %%
#trying to gather all data for next pollutant (nitrogen dioxide)

# %%
#trying to get df for all states/n02 for 2015

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42602&bdate=20150101&edate=20151231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_no2_2015 = urls_list + urls_list2


#creating a base df
df_no2_2015 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_no2_2015:
    try:
        r = requests.get(url)
        data_no2_json = r.json()
        df = pd.DataFrame(data_no2_json['Data'])
        df_no2_2015 = pd.concat([df_no2_2015, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_no2_2015 = df_no2_2015[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_no2_2015

# %%
#trying to get df for all states/n02 for 2016

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42602&bdate=20160101&edate=20161231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_no2_2016 = urls_list + urls_list2


#creating a base df
df_no2_2016 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_no2_2016:
    try:
        r = requests.get(url)
        data_no2_json = r.json()
        df = pd.DataFrame(data_no2_json['Data'])
        df_no2_2016 = pd.concat([df_no2_2016, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_no2_2016 = df_no2_2016[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_no2_2016
#note failed to gather california and texas data

# %%
#trying to get df for all states/n02 for 2017

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42602&bdate=20170101&edate=20171231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_no2_2017 = urls_list + urls_list2


#creating a base df
df_no2_2017 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_no2_2017:
    try:
        r = requests.get(url)
        data_no2_json = r.json()
        df = pd.DataFrame(data_no2_json['Data'])
        df_no2_2017 = pd.concat([df_no2_2017, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_no2_2017 = df_no2_2017[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_no2_2017
#note failed to gather california and texas data

# %%
#trying to get df for all states/n02 for 2018

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42602&bdate=20180101&edate=20181231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_no2_2018 = urls_list + urls_list2


#creating a base df
df_no2_2018 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_no2_2018:
    try:
        r = requests.get(url)
        data_no2_json = r.json()
        df = pd.DataFrame(data_no2_json['Data'])
        df_no2_2018 = pd.concat([df_no2_2018, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_no2_2018 = df_no2_2018[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_no2_2018
#note failed to gather california and texas data

# %%
#trying to get df for all states/n02 for 2019

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42602&bdate=20190101&edate=20191231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_no2_2019 = urls_list + urls_list2


#creating a base df
df_no2_2019 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_no2_2019:
    try:
        r = requests.get(url)
        data_no2_json = r.json()
        df = pd.DataFrame(data_no2_json['Data'])
        df_no2_2019 = pd.concat([df_no2_2019, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_no2_2019 = df_no2_2019[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_no2_2019
#note failed to gather california and texas data

# %%
#trying to get df for all states/n02 for 2020

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42602&bdate=20200101&edate=20201231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_no2_2020 = urls_list + urls_list2


#creating a base df
df_no2_2020 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_no2_2020:
    try:
        r = requests.get(url)
        data_no2_json = r.json()
        df = pd.DataFrame(data_no2_json['Data'])
        df_no2_2020 = pd.concat([df_no2_2020, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_no2_2020 = df_no2_2020[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_no2_2020
#note failed to gather california and texas data

# %%
#concat to one df to export to csv
no2_dfs_temp = [df_no2_2015,df_no2_2016,df_no2_2017,df_no2_2018,df_no2_2019,df_no2_2020]

no2_dfs = pd.concat(no2_dfs_temp)

# %%
no2_dfs.shape

# %%
#dropping all rows with a null value

no2_dfs = no2_dfs.dropna()

# %%
no2_dfs.shape

# %%
no2_dfs.to_csv('nitrogen_dioxide.csv', index=False)

# %%
#trying to gather all data for next pollutant (carbon monoxide)

# %%
#trying to get df for all states/co for 2015

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42101&bdate=20150101&edate=20151231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_co_2015 = urls_list + urls_list2


#creating a base df
df_co_2015 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_co_2015:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_co_2015 = pd.concat([df_co_2015, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_co_2015 = df_co_2015[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_co_2015

# %%
#trying to get df for all states/co for 2016

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42101&bdate=20160101&edate=20161231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_co_2016 = urls_list + urls_list2


#creating a base df
df_co_2016 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_co_2016:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_co_2016 = pd.concat([df_co_2016, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_co_2016 = df_co_2016[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_co_2016

# %%
#trying to get df for all states/co for 2017

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42101&bdate=20170101&edate=20171231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_co_2017 = urls_list + urls_list2


#creating a base df
df_co_2017 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_co_2017:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_co_2017 = pd.concat([df_co_2017, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_co_2017 = df_co_2017[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_co_2017

# %%
#trying to get df for all states/co for 2018

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42101&bdate=20180101&edate=20181231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_co_2018 = urls_list + urls_list2


#creating a base df
df_co_2018 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_co_2018:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_co_2018 = pd.concat([df_co_2018, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_co_2018 = df_co_2018[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_co_2018

# %%
#trying to get df for all states/co for 2019

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42101&bdate=20190101&edate=20191231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_co_2019 = urls_list + urls_list2


#creating a base df
df_co_2019 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_co_2019:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_co_2019 = pd.concat([df_co_2019, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_co_2019 = df_co_2019[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_co_2019

# %%
#trying to get df for all states/co for 2020

#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42101&bdate=20200101&edate=20201231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_co_2020 = urls_list + urls_list2


#creating a base df
df_co_2020 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_co_2020:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_co_2020 = pd.concat([df_co_2020, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_co_2020 = df_co_2020[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_co_2020

# %%
#concat to one df to export to csv
co_dfs_temp = [df_co_2015,df_co_2016,df_co_2017,df_co_2018,df_co_2019,df_co_2020]

co_dfs = pd.concat(co_dfs_temp)

# %%
co_dfs.shape

# %%
#dropping null values
co_dfs = co_dfs.dropna()

# %%
co_dfs.shape

# %%
co_dfs.to_csv('carbon_monoxide.csv', index=False)

# %%
#sulfer dioxide all states 2015-2020

# %%
#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42401&bdate=20150101&edate=20151231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_so2_2015 = urls_list + urls_list2


#creating a base df
df_so2_2015 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_so2_2015:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_so2_2015 = pd.concat([df_so2_2015, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_so2_2015 = df_so2_2015[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_so2_2015

# %%
#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42401&bdate=20160101&edate=20161231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_so2_2016 = urls_list + urls_list2


#creating a base df
df_so2_2016 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_so2_2016:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_so2_2016 = pd.concat([df_so2_2016, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_so2_2016 = df_so2_2016[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_so2_2016

# %%
#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42401&bdate=20170101&edate=20171231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_so2_2017 = urls_list + urls_list2


#creating a base df
df_so2_2017 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_so2_2017:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_so2_2017 = pd.concat([df_so2_2017, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_so2_2017 = df_so2_2017[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_so2_2017

# %%
#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42401&bdate=20180101&edate=20181231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_so2_2018 = urls_list + urls_list2


#creating a base df
df_so2_2018 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_so2_2018:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_so2_2018 = pd.concat([df_so2_2018, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_so2_2018 = df_so2_2018[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_so2_2018

# %%
#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42401&bdate=20190101&edate=20191231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_so2_2019 = urls_list + urls_list2


#creating a base df
df_so2_2019 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_so2_2019:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_so2_2019 = pd.concat([df_so2_2019, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_so2_2019 = df_so2_2019[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_so2_2019

# %%
#obtaining urls list for all states for the desired year
base_url = 'https://aqs.epa.gov/data/api/sampleData/byState?email=erikcpaulson@gmail.com&key=silverkit94&param=42401&bdate=20200101&edate=20201231'

num = 0
urls_list = []
while num<10:
    new_url = base_url + '&state=0' + str(num)
    urls_list.append(new_url)
    num+=1

num2 = 10
urls_list2 = []
while num2<51:
    new_url = base_url + '&state=' + str(num2)
    urls_list2.append(new_url)
    num2+=1

urls_list_so2_2020 = urls_list + urls_list2


#creating a base df
df_so2_2020 = pd.DataFrame(columns = ['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county'])

#creating a comprehensive df
for url in urls_list_so2_2020:
    try:
        r = requests.get(url)
        data_co_json = r.json()
        df = pd.DataFrame(data_co_json['Data'])
        df_so2_2020 = pd.concat([df_so2_2020, df])
    except:
        print('failed at: ', url)

#keeping desired rows    
df_so2_2020 = df_so2_2020[['parameter', 'date_local', 'sample_measurement' , 'units_of_measure', 'state', 'county']]
df_so2_2020

# %%
#ozone or co2 next 42102

# %%
#concat to one df to export to csv
so2_dfs_temp = [df_so2_2015,df_so2_2016,df_so2_2017,df_so2_2018,df_so2_2019,df_so2_2020]

so2_dfs = pd.concat(so2_dfs_temp)

# %%
#dropping null values
so2_dfs = so2_dfs.dropna()

# %%
so2_dfs.to_csv('sulfer_dioxide.csv', index=False)
